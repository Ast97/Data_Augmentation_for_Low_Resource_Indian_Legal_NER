# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/My Drive/data-augmentation-ner-legal-main/")

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting flair==0.10 (from -r requirements.txt (line 1))
#   Downloading flair-0.10-py3-none-any.whl (322 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.7/322.7 kB 26.1 MB/s eta 0:00:00
# Collecting BackTranslation==0.3.1 (from -r requirements.txt (line 2))
#   Downloading BackTranslation-0.3.1-py3-none-any.whl (8.9 kB)
# Collecting beautifulsoup4==4.11.1 (from -r requirements.txt (line 3))
#   Downloading beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 20.2 MB/s eta 0:00:00
# Collecting deepl==1.6.0 (from -r requirements.txt (line 4))
#   Downloading deepl-1.6.0-py3-none-any.whl (31 kB)
# Collecting fasttext==0.9.2 (from -r requirements.txt (line 5))
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 10.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gensim==4.2.0 (from -r requirements.txt (line 6))
#   Downloading gensim-4.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (24.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 60.1 MB/s eta 0:00:00
# Collecting mysql-connector-python==8.0.29 (from -r requirements.txt (line 7))
#   Downloading mysql_connector_python-8.0.29-cp310-cp310-manylinux1_x86_64.whl (25.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.2/25.2 MB 62.9 MB/s eta 0:00:00
# Collecting sacremoses==0.0.53 (from -r requirements.txt (line 8))
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 kB 67.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting SoMaJo==2.2.1 (from -r requirements.txt (line 9))
#   Downloading SoMaJo-2.2.1-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.5/90.5 kB 13.3 MB/s eta 0:00:00
# Collecting tqdm==4.64.0 (from -r requirements.txt (line 10))
#   Downloading tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 12.2 MB/s eta 0:00:00
# Collecting transformers==4.19.1 (from -r requirements.txt (line 11))
#   Downloading transformers-4.19.1-py3-none-any.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 72.4 MB/s eta 0:00:00
# Collecting google-cloud-translate==2.0.1 (from -r requirements.txt (line 12))
#   Downloading google_cloud_translate-2.0.1-py2.py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.10/dist-packages (from flair==0.10->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: torch!=1.8,>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from flair==0.10->-r requirements.txt (line 1)) (2.0.0+cu118)
# Collecting segtok>=1.5.7 (from flair==0.10->-r requirements.txt (line 1))
#   Downloading segtok-1.5.11-py3-none-any.whl (24 kB)
# Requirement already satisfied: matplotlib>=2.2.3 in /usr/local/lib/python3.10/dist-packages (from flair==0.10->-r requirements.txt (line 1)) (3.7.1)
# Collecting mpld3==0.3 (from flair==0.10->-r requirements.txt (line 1))
#   Downloading mpld3-0.3.tar.gz (788 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 788.5/788.5 kB 53.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from flair==0.10->-r requirements.txt (line 1)) (1.2.2)
# Collecting sqlitedict>=1.6.0 (from flair==0.10->-r requirements.txt (line 1))
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Collecting deprecated>=1.2.4 (from flair==0.10->-r requirements.txt (line 1))
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Collecting bpemb>=0.3.2 (from flair==0.10->-r requirements.txt (line 1))
#   Downloading bpemb-0.3.4-py3-none-any.whl (19 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from flair==0.10->-r requirements.txt (line 1)) (2022.10.31)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from flair==0.10->-r requirements.txt (line 1)) (0.8.10)
# Collecting langdetect (from flair==0.10->-r requirements.txt (line 1))
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 76.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from flair==0.10->-r requirements.txt (line 1)) (4.9.2)
# Collecting ftfy (from flair==0.10->-r requirements.txt (line 1))
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 7.9 MB/s eta 0:00:00
# Collecting sentencepiece==0.1.95 (from flair==0.10->-r requirements.txt (line 1))
#   Downloading sentencepiece-0.1.95.tar.gz (508 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 508.7/508.7 kB 46.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting konoha<5.0.0,>=4.0.0 (from flair==0.10->-r requirements.txt (line 1))
#   Downloading konoha-4.6.5-py3-none-any.whl (20 kB)
# Collecting janome (from flair==0.10->-r requirements.txt (line 1))
#   Downloading Janome-0.4.2-py2.py3-none-any.whl (19.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 74.1 MB/s eta 0:00:00
# Collecting gdown==3.12.2 (from flair==0.10->-r requirements.txt (line 1))
#   Downloading gdown-3.12.2.tar.gz (8.2 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting huggingface-hub (from flair==0.10->-r requirements.txt (line 1))
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 30.0 MB/s eta 0:00:00
# Collecting conllu>=4.0 (from flair==0.10->-r requirements.txt (line 1))
#   Downloading conllu-4.5.2-py2.py3-none-any.whl (16 kB)
# Collecting more-itertools~=8.8.0 (from flair==0.10->-r requirements.txt (line 1))
#   Downloading more_itertools-8.8.0-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.8/48.8 kB 6.7 MB/s eta 0:00:00
# Collecting wikipedia-api (from flair==0.10->-r requirements.txt (line 1))
#   Downloading Wikipedia_API-0.5.8-py3-none-any.whl (13 kB)
# Collecting googletrans==4.0.0rc1 (from BackTranslation==0.3.1->-r requirements.txt (line 2))
#   Downloading googletrans-4.0.0rc1.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from BackTranslation==0.3.1->-r requirements.txt (line 2)) (3.8.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4==4.11.1->-r requirements.txt (line 3)) (2.4.1)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from deepl==1.6.0->-r requirements.txt (line 4)) (2.27.1)
# Collecting pybind11>=2.2 (from fasttext==0.9.2->-r requirements.txt (line 5))
#   Using cached pybind11-2.10.4-py3-none-any.whl (222 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext==0.9.2->-r requirements.txt (line 5)) (67.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fasttext==0.9.2->-r requirements.txt (line 5)) (1.22.4)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.10/dist-packages (from gensim==4.2.0->-r requirements.txt (line 6)) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim==4.2.0->-r requirements.txt (line 6)) (6.3.0)
# Requirement already satisfied: protobuf>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from mysql-connector-python==8.0.29->-r requirements.txt (line 7)) (3.20.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from sacremoses==0.0.53->-r requirements.txt (line 8)) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from sacremoses==0.0.53->-r requirements.txt (line 8)) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from sacremoses==0.0.53->-r requirements.txt (line 8)) (1.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.19.1->-r requirements.txt (line 11)) (3.12.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.19.1->-r requirements.txt (line 11)) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.19.1->-r requirements.txt (line 11)) (6.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1 (from transformers==4.19.1->-r requirements.txt (line 11))
#   Downloading tokenizers-0.12.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 92.4 MB/s eta 0:00:00
# Collecting google-api-core[grpc]<2.0.0dev,>=1.15.0 (from google-cloud-translate==2.0.1->-r requirements.txt (line 12))
#   Downloading google_api_core-1.34.0-py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.2/120.2 kB 15.1 MB/s eta 0:00:00
# Collecting google-cloud-core<2.0dev,>=1.1.0 (from google-cloud-translate==2.0.1->-r requirements.txt (line 12))
#   Downloading google_cloud_core-1.7.3-py2.py3-none-any.whl (28 kB)
# Collecting httpx==0.13.3 (from googletrans==4.0.0rc1->BackTranslation==0.3.1->-r requirements.txt (line 2))
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0rc1->BackTranslation==0.3.1->-r requirements.txt (line 2)) (2022.12.7)
# Collecting hstspreload (from httpx==0.13.3->googletrans==4.0.0rc1->BackTranslation==0.3.1->-r requirements.txt (line 2))
#   Downloading hstspreload-2023.1.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 95.9 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0rc1->BackTranslation==0.3.1->-r requirements.txt (line 2)) (1.3.0)
# Collecting chardet==3.* (from httpx==0.13.3->googletrans==4.0.0rc1->BackTranslation==0.3.1->-r requirements.txt (line 2))
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 20.8 MB/s eta 0:00:00
# Collecting idna==2.* (from httpx==0.13.3->googletrans==4.0.0rc1->BackTranslation==0.3.1->-r requirements.txt (line 2))
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.5 MB/s eta 0:00:00
# Collecting rfc3986<2,>=1.3 (from httpx==0.13.3->googletrans==4.0.0rc1->BackTranslation==0.3.1->-r requirements.txt (line 2))
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans==4.0.0rc1->BackTranslation==0.3.1->-r requirements.txt (line 2))
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 5.6 MB/s eta 0:00:00
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0rc1->BackTranslation==0.3.1->-r requirements.txt (line 2))
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 7.9 MB/s eta 0:00:00
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0rc1->BackTranslation==0.3.1->-r requirements.txt (line 2))
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 8.5 MB/s eta 0:00:00
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0rc1->BackTranslation==0.3.1->-r requirements.txt (line 2))
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0rc1->BackTranslation==0.3.1->-r requirements.txt (line 2))
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.4->flair==0.10->-r requirements.txt (line 1)) (1.14.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]<2.0.0dev,>=1.15.0->google-cloud-translate==2.0.1->-r requirements.txt (line 12)) (1.59.0)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]<2.0.0dev,>=1.15.0->google-cloud-translate==2.0.1->-r requirements.txt (line 12)) (2.17.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]<2.0.0dev,>=1.15.0->google-cloud-translate==2.0.1->-r requirements.txt (line 12)) (1.54.0)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]<2.0.0dev,>=1.15.0->google-cloud-translate==2.0.1->-r requirements.txt (line 12)) (1.48.2)
# Collecting google-auth<3.0dev,>=1.25.0 (from google-api-core[grpc]<2.0.0dev,>=1.15.0->google-cloud-translate==2.0.1->-r requirements.txt (line 12))
#   Downloading google_auth-1.35.0-py2.py3-none-any.whl (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.9/152.9 kB 20.1 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->flair==0.10->-r requirements.txt (line 1)) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->flair==0.10->-r requirements.txt (line 1)) (4.5.0)
# Collecting importlib-metadata<4.0.0,>=3.7.0 (from konoha<5.0.0,>=4.0.0->flair==0.10->-r requirements.txt (line 1))
#   Downloading importlib_metadata-3.10.1-py3-none-any.whl (14 kB)
# Collecting overrides<4.0.0,>=3.0.0 (from konoha<5.0.0,>=4.0.0->flair==0.10->-r requirements.txt (line 1))
#   Downloading overrides-3.1.0.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->flair==0.10->-r requirements.txt (line 1)) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->flair==0.10->-r requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->flair==0.10->-r requirements.txt (line 1)) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->flair==0.10->-r requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->flair==0.10->-r requirements.txt (line 1)) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->flair==0.10->-r requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->deepl==1.6.0->-r requirements.txt (line 4)) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->deepl==1.6.0->-r requirements.txt (line 4)) (2.0.12)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->flair==0.10->-r requirements.txt (line 1)) (3.1.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.5.0->flair==0.10->-r requirements.txt (line 1)) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.5.0->flair==0.10->-r requirements.txt (line 1)) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.5.0->flair==0.10->-r requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.5.0->flair==0.10->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch!=1.8,>=1.5.0->flair==0.10->-r requirements.txt (line 1)) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch!=1.8,>=1.5.0->flair==0.10->-r requirements.txt (line 1)) (16.0.3)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ftfy->flair==0.10->-r requirements.txt (line 1)) (0.2.6)
# Collecting cachetools<5.0,>=2.0.0 (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<2.0.0dev,>=1.15.0->google-cloud-translate==2.0.1->-r requirements.txt (line 12))
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<2.0.0dev,>=1.15.0->google-cloud-translate==2.0.1->-r requirements.txt (line 12)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<2.0.0dev,>=1.15.0->google-cloud-translate==2.0.1->-r requirements.txt (line 12)) (4.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<4.0.0,>=3.7.0->konoha<5.0.0,>=4.0.0->flair==0.10->-r requirements.txt (line 1)) (3.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch!=1.8,>=1.5.0->flair==0.10->-r requirements.txt (line 1)) (2.1.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->deepl==1.6.0->-r requirements.txt (line 4)) (1.7.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch!=1.8,>=1.5.0->flair==0.10->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<2.0.0dev,>=1.15.0->google-cloud-translate==2.0.1->-r requirements.txt (line 12)) (0.5.0)
# Building wheels for collected packages: fasttext, sacremoses, gdown, googletrans, mpld3, sentencepiece, sqlitedict, langdetect, overrides
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp310-cp310-linux_x86_64.whl size=4393228 sha256=b36389b53e87a546a42db3944d8eb34db41a8be44c093f3ccac4a34f076623af
#   Stored in directory: /root/.cache/pip/wheels/a5/13/75/f811c84a8ab36eedbaef977a6a58a98990e8e0f1967f98f394
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895241 sha256=3de27e4d43b6bc7e2cb479e98f454857d505dcdeda109554ded913341f9c7320
#   Stored in directory: /root/.cache/pip/wheels/00/24/97/a2ea5324f36bc626e1ea0267f33db6aa80d157ee977e9e42fb
#   Building wheel for gdown (pyproject.toml) ... done
#   Created wheel for gdown: filename=gdown-3.12.2-py3-none-any.whl size=9675 sha256=51c3128df558bd132fb5f6dacfa5c9b4c1598281486b9b57e3d89ee2fd026491
#   Stored in directory: /root/.cache/pip/wheels/fd/45/ac/c7557ccd8fe79de5da94d7b39b5ca92f22f86a0f85367e2b0a
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17397 sha256=89a9d0106c792db4635f339c66c9a2db9398523186ec4f0dac3a8a9c3e546c48
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
#   Building wheel for mpld3 (setup.py) ... done
#   Created wheel for mpld3: filename=mpld3-0.3-py3-none-any.whl size=116685 sha256=62c91996b2be5c0867b046666d303b65f250f5194b4ebc03a15c871d604f9d07
#   Stored in directory: /root/.cache/pip/wheels/9c/92/f7/45d9aac5dcfb1c2a1761a272365599cc7ba1050ce211a3fd9a
#   Building wheel for sentencepiece (setup.py) ... done
#   Created wheel for sentencepiece: filename=sentencepiece-0.1.95-cp310-cp310-linux_x86_64.whl size=1546213 sha256=0c70547f37278dc780f25f994fa08e7681b0a2aaddf63dc6258e9ae758d9a4f7
#   Stored in directory: /root/.cache/pip/wheels/ef/a4/01/5a500fc0c5a38917ef408c245eb40b7ac96f4a30fc6a346a4c
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16863 sha256=ae75fb323fdfc5c46e872d4f3a9c1954e8b06f6e58ee436e7cf788384ede9a92
#   Stored in directory: /root/.cache/pip/wheels/79/d6/e7/304e0e6cb2221022c26d8161f7c23cd4f259a9e41e8bbcfabd
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993224 sha256=9e4990421d3d8d24043856d04fa68f269c2070681d915f3d3ddf16f19d875a6b
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
#   Building wheel for overrides (setup.py) ... done
#   Created wheel for overrides: filename=overrides-3.1.0-py3-none-any.whl size=10173 sha256=13d4c145b2759d8698b20fca581e1498dbd2b25cd47e684f8ad3b74168b61c77
#   Stored in directory: /root/.cache/pip/wheels/bd/23/63/4d5849844f8f9d32be09e1b9b278e80de2d8314fbf1e28068b
# Successfully built fasttext sacremoses gdown googletrans mpld3 sentencepiece sqlitedict langdetect overrides
# Installing collected packages: tokenizers, sqlitedict, sentencepiece, rfc3986, overrides, mpld3, janome, hyperframe, hpack, h11, chardet, tqdm, SoMaJo, segtok, pybind11, mysql-connector-python, more-itertools, langdetect, importlib-metadata, idna, hstspreload, h2, ftfy, deprecated, conllu, cachetools, beautifulsoup4, sacremoses, httpcore, google-auth, gensim, fasttext, wikipedia-api, konoha, huggingface-hub, httpx, google-api-core, deepl, bpemb, transformers, googletrans, google-cloud-core, gdown, google-cloud-translate, BackTranslation, flair
#   Attempting uninstall: chardet
#     Found existing installation: chardet 4.0.0
#     Uninstalling chardet-4.0.0:
#       Successfully uninstalled chardet-4.0.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.65.0
#     Uninstalling tqdm-4.65.0:
#       Successfully uninstalled tqdm-4.65.0
#   Attempting uninstall: more-itertools
#     Found existing installation: more-itertools 9.1.0
#     Uninstalling more-itertools-9.1.0:
#       Successfully uninstalled more-itertools-9.1.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 5.3.0
#     Uninstalling cachetools-5.3.0:
#       Successfully uninstalled cachetools-5.3.0
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.11.2
#     Uninstalling beautifulsoup4-4.11.2:
#       Successfully uninstalled beautifulsoup4-4.11.2
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.17.3
#     Uninstalling google-auth-2.17.3:
#       Successfully uninstalled google-auth-2.17.3
#   Attempting uninstall: gensim
#     Found existing installation: gensim 4.3.1
#     Uninstalling gensim-4.3.1:
#       Successfully uninstalled gensim-4.3.1
#   Attempting uninstall: google-api-core
#     Found existing installation: google-api-core 2.11.0
#     Uninstalling google-api-core-2.11.0:
#       Successfully uninstalled google-api-core-2.11.0
#   Attempting uninstall: google-cloud-core
#     Found existing installation: google-cloud-core 2.3.2
#     Uninstalling google-cloud-core-2.3.2:
#       Successfully uninstalled google-cloud-core-2.3.2
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.6.6
#     Uninstalling gdown-4.6.6:
#       Successfully uninstalled gdown-4.6.6
#   Attempting uninstall: google-cloud-translate
#     Found existing installation: google-cloud-translate 3.11.1
#     Uninstalling google-cloud-translate-3.11.1:
#       Successfully uninstalled google-cloud-translate-3.11.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-auth-oauthlib 1.0.0 requires google-auth>=2.15.0, but you have google-auth 1.35.0 which is incompatible.
# google-cloud-storage 2.8.0 requires google-cloud-core<3.0dev,>=2.3.0, but you have google-cloud-core 1.7.3 which is incompatible.
# Successfully installed BackTranslation-0.3.1 SoMaJo-2.2.1 beautifulsoup4-4.11.1 bpemb-0.3.4 cachetools-4.2.4 chardet-3.0.4 conllu-4.5.2 deepl-1.6.0 deprecated-1.2.13 fasttext-0.9.2 flair-0.10 ftfy-6.1.1 gdown-3.12.2 gensim-4.2.0 google-api-core-1.34.0 google-auth-1.35.0 google-cloud-core-1.7.3 google-cloud-translate-2.0.1 googletrans-4.0.0rc1 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2023.1.1 httpcore-0.9.1 httpx-0.13.3 huggingface-hub-0.14.1 hyperframe-5.2.0 idna-2.10 importlib-metadata-3.10.1 janome-0.4.2 konoha-4.6.5 langdetect-1.0.9 more-itertools-8.8.0 mpld3-0.3 mysql-connector-python-8.0.29 overrides-3.1.0 pybind11-2.10.4 rfc3986-1.5.0 sacremoses-0.0.53 segtok-1.5.11 sentencepiece-0.1.95 sqlitedict-2.1.0 tokenizers-0.12.1 tqdm-4.64.0 transformers-4.19.1 wikipedia-api-0.5.8

# %%
import torch

# Confirm that the GPU is detected

assert torch.cuda.is_available()

# Get the GPU device name.

device_name = torch.cuda.get_device_name()
n_gpu = torch.cuda.device_count()
print(f"Found device: {device_name}, n_gpu: {n_gpu}")
device = torch.device("cuda")

#device = torch.device("cpu")
# Out:
# Found device: Tesla T4, n_gpu: 1

# %%
os.chdir('./src')

# %%
# !python model_bilstm.py datasets/cSR1.0f0.6pftx  datasets/cSR1.0f0.6pftx  0.05 32 gpu
# Out:
# 2023-05-14 05:10:53.912641: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-14 05:10:54.969948: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# 2023-05-14 05:11:04,477 Reading data from datasets/cSR1.0f0.6pftx
# 2023-05-14 05:11:04,477 Train: datasets/cSR1.0f0.6pftx/train.txt
# 2023-05-14 05:11:04,477 Dev: datasets/cSR1.0f0.6pftx/dev.txt
# 2023-05-14 05:11:04,477 Test: datasets/cSR1.0f0.6pftx/test.txt
# 2023-05-14 05:11:13,909 Computing label dictionary. Progress:
# 100% 6031/6031 [00:00<00:00, 6098.83it/s]
# 2023-05-14 05:11:14,938 Corpus contains the labels: ner (#330596)
# 2023-05-14 05:11:14,938 Created (for label 'ner') Dictionary with 30 tags: <unk>, O, B-STATUTE, I-STATUTE, B-JUDGE, B-PRECEDENT, I-PRECEDENT, B-PROVISION, I-PROVISION, B-OTHER_PERSON, B-GPE, B-ORG, I-ORG, B-PETITIONER, B-DATE, B-WITNESS, I-WITNESS, B-COURT, I-COURT, B-CASE_NUMBER, I-CASE_NUMBER, I-OTHER_PERSON, B-RESPONDENT, I-RESPONDENT, I-DATE, I-PETITIONER, I-JUDGE, I-GPE, B-LAWYER, I-LAWYER
# 2023-05-14 05:11:16,268 https://flair.informatik.hu-berlin.de/resources/embeddings/token/en-fasttext-news-300d-1M.vectors.npy not found in cache, downloading to /tmp/tmpvtqtzrnv
# 100% 1200000128/1200000128 [01:31<00:00, 13069221.08B/s]
# 2023-05-14 05:12:48,776 copying /tmp/tmpvtqtzrnv to cache at /root/.flair/embeddings/en-fasttext-news-300d-1M.vectors.npy
# 2023-05-14 05:12:53,217 removing temp file /tmp/tmpvtqtzrnv
# 2023-05-14 05:12:54,355 https://flair.informatik.hu-berlin.de/resources/embeddings/token/en-fasttext-news-300d-1M not found in cache, downloading to /tmp/tmp9dm2bt10
# 100% 54600983/54600983 [00:05<00:00, 9575272.02B/s]
# 2023-05-14 05:13:00,763 copying /tmp/tmp9dm2bt10 to cache at /root/.flair/embeddings/en-fasttext-news-300d-1M
# 2023-05-14 05:13:00,801 removing temp file /tmp/tmp9dm2bt10
# 2023-05-14 05:13:15,362 https://flair.informatik.hu-berlin.de/resources/embeddings/flair/news-forward-0.4.1.pt not found in cache, downloading to /tmp/tmpx7w8jh40
# 100% 73034624/73034624 [00:07<00:00, 10132217.39B/s]
# 2023-05-14 05:13:23,280 copying /tmp/tmpx7w8jh40 to cache at /root/.flair/embeddings/news-forward-0.4.1.pt
# 2023-05-14 05:13:23,351 removing temp file /tmp/tmpx7w8jh40
# 2023-05-14 05:13:25,761 https://flair.informatik.hu-berlin.de/resources/embeddings/flair/news-backward-0.4.1.pt not found in cache, downloading to /tmp/tmpmrel_v6r
# 100% 73034575/73034575 [00:07<00:00, 9550084.28B/s]
# 2023-05-14 05:13:34,115 copying /tmp/tmpmrel_v6r to cache at /root/.flair/embeddings/news-backward-0.4.1.pt
# 2023-05-14 05:13:34,192 removing temp file /tmp/tmpmrel_v6r
# 2023-05-14 05:13:36,693 ----------------------------------------------------------------------------------------------------
# 2023-05-14 05:13:36,694 Model: "SequenceTagger(
#   (embeddings): StackedEmbeddings(
#     (list_embedding_0): WordEmbeddings(
#       'en'
#       (embedding): Embedding(1000001, 300)
#     )
#     (list_embedding_1): FlairEmbeddings(
#       (lm): LanguageModel(
#         (drop): Dropout(p=0.05, inplace=False)
#         (encoder): Embedding(300, 100)
#         (rnn): LSTM(100, 2048)
#         (decoder): Linear(in_features=2048, out_features=300, bias=True)
#       )
#     )
#     (list_embedding_2): FlairEmbeddings(
#       (lm): LanguageModel(
#         (drop): Dropout(p=0.05, inplace=False)
#         (encoder): Embedding(300, 100)
#         (rnn): LSTM(100, 2048)
#         (decoder): Linear(in_features=2048, out_features=300, bias=True)
#       )
#     )
#   )
#   (dropout): Dropout(p=0.25, inplace=False)
#   (word_dropout): WordDropout(p=0.05)
#   (locked_dropout): LockedDropout(p=0.5)
#   (embedding2nn): Linear(in_features=4396, out_features=4396, bias=True)
#   (rnn): LSTM(4396, 256, batch_first=True, bidirectional=True)
#   (linear): Linear(in_features=512, out_features=32, bias=True)
#   (beta): 1.0
#   (weights): None
#   (weight_tensor) None
# )"
# 2023-05-14 05:13:36,694 ----------------------------------------------------------------------------------------------------
# 2023-05-14 05:13:36,694 Corpus: "Corpus: 6031 train + 4109 dev + 982 test sentences"
# 2023-05-14 05:13:36,694 ----------------------------------------------------------------------------------------------------
# 2023-05-14 05:13:36,694 Parameters:
# 2023-05-14 05:13:36,695  - learning_rate: "0.05"
# 2023-05-14 05:13:36,695  - mini_batch_size: "32"
# 2023-05-14 05:13:36,695  - patience: "5"
# 2023-05-14 05:13:36,695  - anneal_factor: "0.5"
# 2023-05-14 05:13:36,695  - max_epochs: "10"
# 2023-05-14 05:13:36,695  - shuffle: "True"
# 2023-05-14 05:13:36,695  - train_with_dev: "False"
# 2023-05-14 05:13:36,696  - batch_growth_annealing: "False"
# 2023-05-14 05:13:36,696 ----------------------------------------------------------------------------------------------------
# 2023-05-14 05:13:36,696 Model training base path: "resources/taggers/sota-ner-flair"
# 2023-05-14 05:13:36,696 ----------------------------------------------------------------------------------------------------
# 2023-05-14 05:13:36,696 Device: cuda:0
# 2023-05-14 05:13:36,696 ----------------------------------------------------------------------------------------------------
# 2023-05-14 05:13:36,696 Embeddings storage mode: gpu
# /usr/local/lib/python3.10/dist-packages/flair/trainers/trainer.py:64: UserWarning: There should be no best model saved at epoch 1 except there is a model from previous trainings in your training folder. All previous best models will be deleted.
#   warnings.warn(
# 2023-05-14 05:13:37,534 ----------------------------------------------------------------------------------------------------
# 2023-05-14 05:13:48,803 epoch 1 - iter 18/189 - loss 1.55478971 - samples/sec: 51.13 - lr: 0.050000
# 2023-05-14 05:13:59,209 epoch 1 - iter 36/189 - loss 1.18256722 - samples/sec: 55.37 - lr: 0.050000
# 2023-05-14 05:14:09,306 epoch 1 - iter 54/189 - loss 1.04890998 - samples/sec: 57.06 - lr: 0.050000
# 2023-05-14 05:14:19,928 epoch 1 - iter 72/189 - loss 0.95101277 - samples/sec: 54.24 - lr: 0.050000
# 2023-05-14 05:14:32,352 epoch 1 - iter 90/189 - loss 0.86753847 - samples/sec: 46.37 - lr: 0.050000
# 2023-05-14 05:14:43,087 epoch 1 - iter 108/189 - loss 0.80776608 - samples/sec: 53.67 - lr: 0.050000
# 2023-05-14 05:14:54,207 epoch 1 - iter 126/189 - loss 0.76729567 - samples/sec: 51.81 - lr: 0.050000
# 2023-05-14 05:15:43,025 epoch 1 - iter 144/189 - loss 0.84415401 - samples/sec: 11.80 - lr: 0.050000
# 2023-05-14 05:17:09,024 epoch 1 - iter 162/189 - loss 0.83130939 - samples/sec: 6.70 - lr: 0.050000
# 2023-05-14 05:18:49,504 epoch 1 - iter 180/189 - loss 0.80411177 - samples/sec: 5.73 - lr: 0.050000
# 2023-05-14 05:19:05,648 ----------------------------------------------------------------------------------------------------
# 2023-05-14 05:19:05,649 EPOCH 1 done: loss 0.8007 - lr 0.0500000
# 2023-05-14 05:20:23,360 DEV : loss 0.45420345664024353 - f1-score (micro avg)  0.2105
# 2023-05-14 05:20:23,424 BAD EPOCHS (no improvement): 0
# 2023-05-14 05:20:24,206 saving best model
# 2023-05-14 05:21:13,251 ----------------------------------------------------------------------------------------------------
# 2023-05-14 05:21:24,056 epoch 2 - iter 18/189 - loss 0.59329389 - samples/sec: 53.32 - lr: 0.050000
# 2023-05-14 05:21:38,596 epoch 2 - iter 36/189 - loss 0.59053181 - samples/sec: 39.64 - lr: 0.050000
# 2023-05-14 05:21:49,998 epoch 2 - iter 54/189 - loss 0.57919371 - samples/sec: 50.53 - lr: 0.050000
# 2023-05-14 05:22:02,071 epoch 2 - iter 72/189 - loss 0.56258316 - samples/sec: 47.73 - lr: 0.050000
# 2023-05-14 05:22:14,429 epoch 2 - iter 90/189 - loss 0.54441592 - samples/sec: 46.63 - lr: 0.050000
# 2023-05-14 05:22:28,333 epoch 2 - iter 108/189 - loss 0.52586990 - samples/sec: 41.44 - lr: 0.050000
# 2023-05-14 05:22:36,834 epoch 2 - iter 126/189 - loss 0.51552299 - samples/sec: 67.82 - lr: 0.050000
# 2023-05-14 05:22:47,418 epoch 2 - iter 144/189 - loss 0.50922326 - samples/sec: 54.46 - lr: 0.050000
# 2023-05-14 05:22:58,965 epoch 2 - iter 162/189 - loss 0.49715473 - samples/sec: 49.90 - lr: 0.050000
# 2023-05-14 05:23:08,694 epoch 2 - iter 180/189 - loss 0.48934738 - samples/sec: 59.24 - lr: 0.050000
# 2023-05-14 05:23:14,732 ----------------------------------------------------------------------------------------------------
# 2023-05-14 05:23:14,733 EPOCH 2 done: loss 0.4854 - lr 0.0500000
# 2023-05-14 05:23:31,970 DEV : loss 0.3458409607410431 - f1-score (micro avg)  0.383
# 2023-05-14 05:23:31,998 BAD EPOCHS (no improvement): 0
# 2023-05-14 05:23:32,746 saving best model
# 2023-05-14 05:23:59,709 ----------------------------------------------------------------------------------------------------
# 2023-05-14 05:24:09,461 epoch 3 - iter 18/189 - loss 0.37058593 - samples/sec: 59.08 - lr: 0.050000
# 2023-05-14 05:24:22,179 epoch 3 - iter 36/189 - loss 0.36789532 - samples/sec: 45.30 - lr: 0.050000
# 2023-05-14 05:24:36,384 epoch 3 - iter 54/189 - loss 0.36614923 - samples/sec: 40.56 - lr: 0.050000
# 2023-05-14 05:24:47,678 epoch 3 - iter 72/189 - loss 0.36632842 - samples/sec: 51.03 - lr: 0.050000
# 2023-05-14 05:24:57,411 epoch 3 - iter 90/189 - loss 0.35842570 - samples/sec: 59.20 - lr: 0.050000
# 2023-05-14 05:25:07,232 epoch 3 - iter 108/189 - loss 0.35497615 - samples/sec: 58.69 - lr: 0.050000
# 2023-05-14 05:25:18,758 epoch 3 - iter 126/189 - loss 0.34648894 - samples/sec: 50.00 - lr: 0.050000
# 2023-05-14 05:25:29,294 epoch 3 - iter 144/189 - loss 0.34056548 - samples/sec: 54.69 - lr: 0.050000
# 2023-05-14 05:25:43,996 epoch 3 - iter 162/189 - loss 0.33662748 - samples/sec: 39.20 - lr: 0.050000
# 2023-05-14 05:25:55,422 epoch 3 - iter 180/189 - loss 0.33705285 - samples/sec: 50.43 - lr: 0.050000
# 2023-05-14 05:26:00,198 ----------------------------------------------------------------------------------------------------
# 2023-05-14 05:26:00,201 EPOCH 3 done: loss 0.3361 - lr 0.0500000
# 2023-05-14 05:26:15,040 DEV : loss 0.25808990001678467 - f1-score (micro avg)  0.506
# 2023-05-14 05:26:15,098 BAD EPOCHS (no improvement): 0
# 2023-05-14 05:26:15,826 saving best model
# 2023-05-14 05:26:22,887 ----------------------------------------------------------------------------------------------------
# 2023-05-14 05:26:34,810 epoch 4 - iter 18/189 - loss 0.27463808 - samples/sec: 48.32 - lr: 0.050000
# 2023-05-14 05:26:46,073 epoch 4 - iter 36/189 - loss 0.28487624 - samples/sec: 51.17 - lr: 0.050000
# 2023-05-14 05:26:55,888 epoch 4 - iter 54/189 - loss 0.29053948 - samples/sec: 58.73 - lr: 0.050000
# 2023-05-14 05:27:08,862 epoch 4 - iter 72/189 - loss 0.28305194 - samples/sec: 44.41 - lr: 0.050000
# 2023-05-14 05:27:20,202 epoch 4 - iter 90/189 - loss 0.28163228 - samples/sec: 50.81 - lr: 0.050000
# 2023-05-14 05:27:31,004 epoch 4 - iter 108/189 - loss 0.27909830 - samples/sec: 53.36 - lr: 0.050000
# 2023-05-14 05:27:40,865 epoch 4 - iter 126/189 - loss 0.27795009 - samples/sec: 58.45 - lr: 0.050000
# 2023-05-14 05:27:52,273 epoch 4 - iter 144/189 - loss 0.27131029 - samples/sec: 50.50 - lr: 0.050000
# 2023-05-14 05:28:01,150 epoch 4 - iter 162/189 - loss 0.26807241 - samples/sec: 64.93 - lr: 0.050000
# 2023-05-14 05:28:17,577 epoch 4 - iter 180/189 - loss 0.26425575 - samples/sec: 35.07 - lr: 0.050000
# 2023-05-14 05:28:22,278 ----------------------------------------------------------------------------------------------------
# 2023-05-14 05:28:22,283 EPOCH 4 done: loss 0.2628 - lr 0.0500000
# 2023-05-14 05:28:39,539 DEV : loss 0.20987515151500702 - f1-score (micro avg)  0.5643
# 2023-05-14 05:28:39,568 BAD EPOCHS (no improvement): 0
# 2023-05-14 05:28:40,311 saving best model
# 2023-05-14 05:28:50,618 ----------------------------------------------------------------------------------------------------
# 2023-05-14 05:29:00,072 epoch 5 - iter 18/189 - loss 0.26189062 - samples/sec: 60.95 - lr: 0.050000
# 2023-05-14 05:29:10,386 epoch 5 - iter 36/189 - loss 0.25199084 - samples/sec: 55.87 - lr: 0.050000
# 2023-05-14 05:29:29,153 epoch 5 - iter 54/189 - loss 0.23830792 - samples/sec: 30.70 - lr: 0.050000
# 2023-05-14 05:29:40,585 epoch 5 - iter 72/189 - loss 0.23683803 - samples/sec: 50.41 - lr: 0.050000
# 2023-05-14 05:29:51,988 epoch 5 - iter 90/189 - loss 0.23393699 - samples/sec: 50.53 - lr: 0.050000
# 2023-05-14 05:30:02,973 epoch 5 - iter 108/189 - loss 0.22783795 - samples/sec: 52.46 - lr: 0.050000
# 2023-05-14 05:30:13,948 epoch 5 - iter 126/189 - loss 0.22539740 - samples/sec: 52.51 - lr: 0.050000
# 2023-05-14 05:30:24,751 epoch 5 - iter 144/189 - loss 0.22695036 - samples/sec: 53.34 - lr: 0.050000
# 2023-05-14 05:30:33,162 epoch 5 - iter 162/189 - loss 0.22562768 - samples/sec: 68.54 - lr: 0.050000
# 2023-05-14 05:30:44,067 epoch 5 - iter 180/189 - loss 0.22451539 - samples/sec: 52.84 - lr: 0.050000
# 2023-05-14 05:30:50,089 ----------------------------------------------------------------------------------------------------
# 2023-05-14 05:30:50,093 EPOCH 5 done: loss 0.2239 - lr 0.0500000
# 2023-05-14 05:31:05,963 DEV : loss 0.19034728407859802 - f1-score (micro avg)  0.5991
# 2023-05-14 05:31:05,991 BAD EPOCHS (no improvement): 0
# 2023-05-14 05:31:05,995 saving best model
# 2023-05-14 05:31:24,390 ----------------------------------------------------------------------------------------------------
# 2023-05-14 05:31:34,282 epoch 6 - iter 18/189 - loss 0.19111106 - samples/sec: 58.25 - lr: 0.050000
# 2023-05-14 05:31:45,667 epoch 6 - iter 36/189 - loss 0.19559675 - samples/sec: 50.64 - lr: 0.050000
# 2023-05-14 05:31:57,355 epoch 6 - iter 54/189 - loss 0.19238451 - samples/sec: 49.31 - lr: 0.050000
# 2023-05-14 05:32:15,589 epoch 6 - iter 72/189 - loss 0.18889796 - samples/sec: 31.60 - lr: 0.050000
# 2023-05-14 05:32:27,086 epoch 6 - iter 90/189 - loss 0.18805732 - samples/sec: 50.12 - lr: 0.050000
# 2023-05-14 05:32:39,113 epoch 6 - iter 108/189 - loss 0.19268952 - samples/sec: 47.91 - lr: 0.050000
# 2023-05-14 05:32:47,300 epoch 6 - iter 126/189 - loss 0.19470739 - samples/sec: 70.41 - lr: 0.050000
# 2023-05-14 05:32:58,605 epoch 6 - iter 144/189 - loss 0.19348613 - samples/sec: 50.98 - lr: 0.050000
# 2023-05-14 05:33:09,803 epoch 6 - iter 162/189 - loss 0.19229004 - samples/sec: 51.45 - lr: 0.050000
# 2023-05-14 05:33:20,025 epoch 6 - iter 180/189 - loss 0.19206508 - samples/sec: 56.36 - lr: 0.050000
# 2023-05-14 05:33:25,714 ----------------------------------------------------------------------------------------------------
# 2023-05-14 05:33:25,718 EPOCH 6 done: loss 0.1914 - lr 0.0500000
# 2023-05-14 05:33:43,099 DEV : loss 0.18039467930793762 - f1-score (micro avg)  0.6221
# 2023-05-14 05:33:43,128 BAD EPOCHS (no improvement): 0
# 2023-05-14 05:33:43,132 saving best model
# 2023-05-14 05:33:52,407 ----------------------------------------------------------------------------------------------------
# 2023-05-14 05:34:04,850 epoch 7 - iter 18/189 - loss 0.18214118 - samples/sec: 46.30 - lr: 0.050000
# 2023-05-14 05:34:18,861 epoch 7 - iter 36/189 - loss 0.18237645 - samples/sec: 41.12 - lr: 0.050000
# 2023-05-14 05:34:30,730 epoch 7 - iter 54/189 - loss 0.18595749 - samples/sec: 48.58 - lr: 0.050000
# 2023-05-14 05:34:42,255 epoch 7 - iter 72/189 - loss 0.18791784 - samples/sec: 50.00 - lr: 0.050000
# 2023-05-14 05:34:58,696 epoch 7 - iter 90/189 - loss 0.18238674 - samples/sec: 35.04 - lr: 0.050000
# 2023-05-14 05:35:10,969 epoch 7 - iter 108/189 - loss 0.17979031 - samples/sec: 46.96 - lr: 0.050000
# 2023-05-14 05:35:20,298 epoch 7 - iter 126/189 - loss 0.18070610 - samples/sec: 61.78 - lr: 0.050000
# 2023-05-14 05:35:29,791 epoch 7 - iter 144/189 - loss 0.17996359 - samples/sec: 60.72 - lr: 0.050000
# 2023-05-14 05:35:41,435 epoch 7 - iter 162/189 - loss 0.17977421 - samples/sec: 49.48 - lr: 0.050000
# 2023-05-14 05:35:51,371 epoch 7 - iter 180/189 - loss 0.17868003 - samples/sec: 57.99 - lr: 0.050000
# 2023-05-14 05:35:56,866 ----------------------------------------------------------------------------------------------------
# 2023-05-14 05:35:56,871 EPOCH 7 done: loss 0.1785 - lr 0.0500000
# 2023-05-14 05:36:14,290 DEV : loss 0.1452753096818924 - f1-score (micro avg)  0.6619
# 2023-05-14 05:36:14,318 BAD EPOCHS (no improvement): 0
# 2023-05-14 05:36:14,321 saving best model
# 2023-05-14 05:36:21,466 ----------------------------------------------------------------------------------------------------
# 2023-05-14 05:36:32,155 epoch 8 - iter 18/189 - loss 0.17733615 - samples/sec: 53.91 - lr: 0.050000
# 2023-05-14 05:36:51,585 epoch 8 - iter 36/189 - loss 0.17241685 - samples/sec: 29.65 - lr: 0.050000
# 2023-05-14 05:37:04,317 epoch 8 - iter 54/189 - loss 0.16438586 - samples/sec: 45.25 - lr: 0.050000
# 2023-05-14 05:37:16,396 epoch 8 - iter 72/189 - loss 0.16529042 - samples/sec: 47.70 - lr: 0.050000
# 2023-05-14 05:37:28,524 epoch 8 - iter 90/189 - loss 0.16554928 - samples/sec: 47.52 - lr: 0.050000
# 2023-05-14 05:37:38,219 epoch 8 - iter 108/189 - loss 0.16410286 - samples/sec: 59.43 - lr: 0.050000
# 2023-05-14 05:37:49,285 epoch 8 - iter 126/189 - loss 0.16471645 - samples/sec: 52.06 - lr: 0.050000
# 2023-05-14 05:37:59,524 epoch 8 - iter 144/189 - loss 0.16198504 - samples/sec: 56.28 - lr: 0.050000
# 2023-05-14 05:38:08,585 epoch 8 - iter 162/189 - loss 0.16285194 - samples/sec: 63.62 - lr: 0.050000
# 2023-05-14 05:38:18,809 epoch 8 - iter 180/189 - loss 0.16121738 - samples/sec: 56.37 - lr: 0.050000
# 2023-05-14 05:38:23,233 ----------------------------------------------------------------------------------------------------
# 2023-05-14 05:38:23,238 EPOCH 8 done: loss 0.1606 - lr 0.0500000
# 2023-05-14 05:38:39,917 DEV : loss 0.1417466551065445 - f1-score (micro avg)  0.6705
# 2023-05-14 05:38:39,947 BAD EPOCHS (no improvement): 0
# 2023-05-14 05:38:40,716 saving best model
# 2023-05-14 05:38:54,583 ----------------------------------------------------------------------------------------------------
# 2023-05-14 05:39:12,732 epoch 9 - iter 18/189 - loss 0.12651739 - samples/sec: 31.75 - lr: 0.050000
# 2023-05-14 05:39:25,394 epoch 9 - iter 36/189 - loss 0.13855660 - samples/sec: 45.52 - lr: 0.050000
# 2023-05-14 05:39:35,869 epoch 9 - iter 54/189 - loss 0.14524827 - samples/sec: 55.02 - lr: 0.050000
# 2023-05-14 05:39:50,234 epoch 9 - iter 72/189 - loss 0.14297251 - samples/sec: 40.11 - lr: 0.050000
# 2023-05-14 05:39:59,252 epoch 9 - iter 90/189 - loss 0.14335232 - samples/sec: 63.89 - lr: 0.050000
# 2023-05-14 05:40:10,871 epoch 9 - iter 108/189 - loss 0.14478525 - samples/sec: 49.59 - lr: 0.050000
# 2023-05-14 05:40:21,560 epoch 9 - iter 126/189 - loss 0.14452492 - samples/sec: 53.90 - lr: 0.050000
# 2023-05-14 05:40:33,531 epoch 9 - iter 144/189 - loss 0.14484625 - samples/sec: 48.15 - lr: 0.050000
# 2023-05-14 05:40:43,124 epoch 9 - iter 162/189 - loss 0.14697755 - samples/sec: 60.06 - lr: 0.050000
# 2023-05-14 05:40:53,174 epoch 9 - iter 180/189 - loss 0.14638107 - samples/sec: 57.36 - lr: 0.050000
# 2023-05-14 05:40:57,323 ----------------------------------------------------------------------------------------------------
# 2023-05-14 05:40:57,325 EPOCH 9 done: loss 0.1456 - lr 0.0500000
# 2023-05-14 05:41:15,363 DEV : loss 0.1366291493177414 - f1-score (micro avg)  0.6749
# 2023-05-14 05:41:15,391 BAD EPOCHS (no improvement): 0
# 2023-05-14 05:41:16,171 saving best model
# 2023-05-14 05:41:29,712 ----------------------------------------------------------------------------------------------------
# 2023-05-14 05:41:42,018 epoch 10 - iter 18/189 - loss 0.14096109 - samples/sec: 46.82 - lr: 0.050000
# 2023-05-14 05:41:53,392 epoch 10 - iter 36/189 - loss 0.14523893 - samples/sec: 50.68 - lr: 0.050000
# 2023-05-14 05:42:09,168 epoch 10 - iter 54/189 - loss 0.13882243 - samples/sec: 36.53 - lr: 0.050000
# 2023-05-14 05:42:17,320 epoch 10 - iter 72/189 - loss 0.13788940 - samples/sec: 70.67 - lr: 0.050000
# 2023-05-14 05:42:29,247 epoch 10 - iter 90/189 - loss 0.13965841 - samples/sec: 48.33 - lr: 0.050000
# 2023-05-14 05:42:40,828 epoch 10 - iter 108/189 - loss 0.13757216 - samples/sec: 49.75 - lr: 0.050000
# 2023-05-14 05:42:50,285 epoch 10 - iter 126/189 - loss 0.13501067 - samples/sec: 60.95 - lr: 0.050000
# 2023-05-14 05:43:02,051 epoch 10 - iter 144/189 - loss 0.13732052 - samples/sec: 48.97 - lr: 0.050000
# 2023-05-14 05:43:16,554 epoch 10 - iter 162/189 - loss 0.13599308 - samples/sec: 39.73 - lr: 0.050000
# 2023-05-14 05:43:26,523 epoch 10 - iter 180/189 - loss 0.13603787 - samples/sec: 57.81 - lr: 0.050000
# 2023-05-14 05:43:30,760 ----------------------------------------------------------------------------------------------------
# 2023-05-14 05:43:30,763 EPOCH 10 done: loss 0.1359 - lr 0.0500000
# 2023-05-14 05:43:47,392 DEV : loss 0.1207338273525238 - f1-score (micro avg)  0.6991
# 2023-05-14 05:43:47,420 BAD EPOCHS (no improvement): 0
# 2023-05-14 05:43:48,213 saving best model
# 2023-05-14 05:44:37,184 ----------------------------------------------------------------------------------------------------
# 2023-05-14 05:44:37,391 loading file resources/taggers/sota-ner-flair/best-model.pt
# 2023-05-14 05:45:29,823 0.802	0.7936	0.7978	0.6927
# 2023-05-14 05:45:29,823
# Results:
# - F-score (micro) 0.7978
# - F-score (macro) 0.7185
# - Accuracy 0.6927
#
# By class:
#               precision    recall  f1-score   support
#
#       LAWYER     0.9413    0.9253    0.9332       589
#   RESPONDENT     0.8241    0.7587    0.7901       315
# OTHER_PERSON     0.7298    0.8514    0.7860       276
#        COURT     0.8179    0.8041    0.8109       296
#    PROVISION     0.8566    0.8566    0.8566       258
#         DATE     0.8566    0.9414    0.8970       222
#      STATUTE     0.8025    0.8604    0.8304       222
#   PETITIONER     0.8485    0.7962    0.8215       211
#          GPE     0.7207    0.7049    0.7127       183
#    PRECEDENT     0.6923    0.6610    0.6763       177
#          ORG     0.5185    0.5283    0.5234       159
#        JUDGE     0.8741    0.7184    0.7886       174
#  CASE_NUMBER     0.5649    0.7190    0.6327       121
#      WITNESS     0.0000    0.0000    0.0000        58
#
#    micro avg     0.8020    0.7936    0.7978      3261
#    macro avg     0.7177    0.7233    0.7185      3261
# weighted avg     0.7921    0.7936    0.7913      3261
#  samples avg     0.6927    0.6927    0.6927      3261
#
# 2023-05-14 05:45:29,824 ----------------------------------------------------------------------------------------------------
# 2023-05-14 05:45:29,851 loading file resources/taggers/sota-ner-flair/final-model.pt
